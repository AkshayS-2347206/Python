# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('fifa_eda_stats.csv')
df.head(10)
# Out:
#        ID               Name  Age Nationality  Potential                 Club  \
# 0  158023           L. Messi   31   Argentina         94         FC Barcelona
# 1   20801  Cristiano Ronaldo   33    Portugal         94             Juventus
# 2  190871          Neymar Jr   26      Brazil         93  Paris Saint-Germain
# 3  193080             De Gea   27       Spain         93    Manchester United
# 4  192985       K. De Bruyne   27     Belgium         92      Manchester City
# 5  183277          E. Hazard   27     Belgium         91              Chelsea
# 6  177003          L. Modrić   32     Croatia         91          Real Madrid
# 7  176580          L. Suárez   31     Uruguay         91         FC Barcelona
# 8  155862       Sergio Ramos   32       Spain         91          Real Madrid
# 9  200389           J. Oblak   25    Slovenia         93      Atlético Madrid
#
#    Skill Moves Position  Jersey Number Height  ... Finishing  Dribbling  \
# ...

# %% [markdown]
# # New section

# %%
df.corr()
# Out:
# <ipython-input-11-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      ID       Age  Potential  Skill Moves  Jersey Number  \
# ID             1.000000 -0.738023   0.136015     0.047839       0.212713
# Age           -0.738023  1.000000  -0.427954    -0.264540      -0.135135
# Potential      0.136015 -0.427954   1.000000     0.118561      -0.067294
# Skill Moves    0.047839 -0.264540   0.118561     1.000000       0.121181
# Jersey Number  0.212713 -0.135135  -0.067294     0.121181       1.000000
# Finishing      0.069562 -0.162632  -0.001965     0.788270       0.150015
# Dribbling      0.083639 -0.191563  -0.046280     0.851772       0.196170
# SprintSpeed    0.182836 -0.322458   0.149321     0.622180       0.178448
# ...

# %%
corr = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr)
plt.show()
# Out:
# <ipython-input-12-bab1171a0129>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
x = df["Position"][0:20]
y = df["Name"][0:20]
plt.scatter(x, y)
plt.show()

# %%
x = df["Name"][0:5]
y = df["Penalties"][0:5]
plt.xlabel('Name')
plt.ylabel('Penalties')
plt.title('Player Penalties')
plt.bar(x, y)
plt.show()

# %%
plot = df["Skill Moves"].value_counts().plot(kind="bar")
plt.xlabel('Skills')
plt.ylabel('Count')
plt.title('Number of Player Skills')
plt.show()

# %%
plot = df["Stamina"].value_counts().plot(kind="line")
plt.ylabel('Count')
plt.title('Player Stamina')
plt.show()

# %%
plot = df["Weight"].value_counts().plot(kind="line")
plt.ylabel('Count')
plt.title('Player Weights')
plt.show()
